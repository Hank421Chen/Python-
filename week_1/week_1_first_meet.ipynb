# %%
import pandas as pd

# %%
df = pd.read_csv('../../NTU_BigData_And_BusinessAnalyzation_Datasets/PromotionOrders.csv')

# %%
df.head()
# Out:
#    SalesOrderSlaveId  PromotionId  SalesOrderSlavePromotionDiscount  \
# 0           40086585        62671                             100.0
# 1           40088089        62671                             100.0
# 2           40090756        62671                             100.0
# 3           40090763        62671                             100.0
# 4           40091003        62671                             100.0
#
#    SalesOrderSlavePromotionDiscountAllocated  \
# 0                                      -12.0
# 1                                      -12.0
# 2                                      -12.0
# 3                                      -12.0
# 4                                      -12.0
#
#    SalesOrderSlavePromotionDiscountAllocatedQty  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# ...

# %%
df.tail()
# Out:
#          SalesOrderSlaveId  PromotionId  SalesOrderSlavePromotionDiscount  \
# 4011059           21412222        34032                             200.0
# 4011060           21421957        34032                             200.0
# 4011061           21479425        34032                             200.0
# 4011062           21480877        34032                             200.0
# 4011063           21489721        34032                             200.0
#
#          SalesOrderSlavePromotionDiscountAllocated  \
# 4011059                                      -46.0
# 4011060                                      -44.0
# 4011061                                     -200.0
# 4011062                                     -150.0
# 4011063                                      -94.0
#
#          SalesOrderSlavePromotionDiscountAllocatedQty  \
# 4011059                                             3
# 4011060                                             3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4011064 entries, 0 to 4011063
# Data columns (total 13 columns):
# SalesOrderSlaveId                               int64
# PromotionId                                     int64
# SalesOrderSlavePromotionDiscount                float64
# SalesOrderSlavePromotionDiscountAllocated       float64
# SalesOrderSlavePromotionDiscountAllocatedQty    int64
# SalesOrderSlavePromotionDiscountRate            float64
# DiscountType                                    object
# PromotionCondition_DiscountPrice                float64
# PromotionCondition_DiscountRate                 float64
# PromotionCondition_TotalPrice                   float64
# PromotionCondition_TotalQty                     int64
# PromotionStartDateTime                          object
# PromotionEndDateTime                            object
# dtypes: float64(6), int64(4), object(3)
# memory usage: 397.8+ MB

# %%
df.shape
# Out:
# (4011064, 13)

# %%
df['PromotionCondition_TotalPrice'].head(10)
# Out:
# 0    1000.0
# 1    1000.0
# 2    1000.0
# 3    1000.0
# 4    1000.0
# 5    1000.0
# 6    1000.0
# 7    1000.0
# 8    1000.0
# 9    1000.0
# Name: PromotionCondition_TotalPrice, dtype: float64

# %%
df.loc[10]
# Out:
# SalesOrderSlaveId                                              40097342
# PromotionId                                                       62671
# SalesOrderSlavePromotionDiscount                                    100
# SalesOrderSlavePromotionDiscountAllocated                           -12
# SalesOrderSlavePromotionDiscountAllocatedQty                          1
# SalesOrderSlavePromotionDiscountRate                                  0
# DiscountType                                                       滿額折現
# PromotionCondition_DiscountPrice                                    100
# PromotionCondition_DiscountRate                                       0
# PromotionCondition_TotalPrice                                      1000
# PromotionCondition_TotalQty                                           0
# PromotionStartDateTime                          2017-07-10 11:00:00.000
# PromotionEndDateTime                            2017-07-31 10:59:00.000
# Name: 10, dtype: object

# %%
df.loc[1:10, ['PromotionCondition_DiscountPrice', 'DiscountType']]
# Out:
#     PromotionCondition_DiscountPrice DiscountType
# 1                              100.0         滿額折現
# 2                              100.0         滿額折現
# 3                              100.0         滿額折現
# 4                              100.0         滿額折現
# 5                              100.0         滿額折現
# 6                              100.0         滿額折現
# 7                              100.0         滿額折現
# 8                              100.0         滿額折現
# 9                              100.0         滿額折現
# 10                             100.0         滿額折現

# %%
df[df['PromotionCondition_DiscountPrice'] > 500]
# Out:
#          SalesOrderSlaveId  PromotionId  SalesOrderSlavePromotionDiscount  \
# 1235407           27879196        38042                             550.0
# 1235408           27879198        38042                             550.0
# 1338569           26336942        38040                             599.0
# 1338570           26336943        38040                             599.0
# 1338571           26497349        38040                             599.0
# 1338572           26502077        38040                             599.0
# 1338573           26502081        38040                             599.0
# 1338574           26573214        38040                             599.0
# 1338575           26573216        38040                             599.0
# 1338576           26573217        38040                             599.0
# 1338577           26573218        38040                             599.0
# 1338578           26573850        38040                             599.0
# ...

# %%
data = df.groupby(by='DiscountType')['PromotionCondition_DiscountPrice'].sum()
for i in range(len(data)):
    data[i] = int(data[i])
data
# Out:
# DiscountType
# 任選優惠價     215620207.0
# 會員滿額打折            0.0
# 滿件打折              0.0
# 滿件折現        5256248.0
# 滿額打折              0.0
# 滿額折現      209223124.0
# 滿額贈               0.0
# Name: PromotionCondition_DiscountPrice, dtype: float64

# %%
import matplotlib.pyplot as plt
#plt.rcParams['font.family']= ['SimHei']
#plt.rcParams['font.sans-serif'] = ['SimHei']
#plt.rcParams['axes.unicode_minus'] = False
# %matplotlib inline
#labels = [u'任選優惠價',u'會員滿額打折',u'滿件打折',u'滿件折現',u'滿額打折',u'滿額折現 ',u'滿額贈']
#size = [data[i] for i in range(len(data))]
labels = ['Discount1','Discount2','Discount3']
size = [data[0],data[3],data[-2]]
plt.pie(size, labels = labels,autopct='%1.1f%%')
plt.axis('equal')
plt.show()
