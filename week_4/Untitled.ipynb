# %%
data = open("2705 2017 六福.txt", "r", encoding="utf-8")
data2= data.readlines()

# %%
data2
# Out:
# ['\n',
#  '\n',
#  '! ! \n',
#  '\n',
#  'ި౻жዸǺ3816 ! \n',
#  '! \n',
#  '! \n',
#  '! \n',
#  '!\n',
#  '! \n',
#  '! \n',
#  '!\n',
#  '! \n',
#  '! \n',
#  '!\n',
#  '! \n',
#  '! \n',
#  'Ϥᅽ໒วިҽԖज़Ϧљ ! \n',
#  'MFPGPP!EFWFMPQNFOU!DP/-!MUE/! \n',
#  '! \n',
#  '! \n',
#  '! \n',
#  '! \n',
#  '\u038b\u2002䐠Ϥ\u2005̠ࡋ\u2005̠ൔ\u2000 \n',
#  '! \n',
#  '\n',
#  '! \n',
#  '! \n',
#  '!\n',
#  '! \n',
#  'ёԿ\u2003ꀄ젠ᆛ֟\u2008霐䰠ҁԃ\u200d吐圠\u0a11! \n',
#  'iu\u2000甀焁切\u3000\u3000渀瀠qt/u\u2000砀琀昀⼠dpn/\u2000甀砀 \n',
#  '! \n',
#  'ύ\u0e6e҇୯\u038bɄΎԃϖДΐВтӑ!\n',
#  '\n',
#  '! ! \n',
#  '\n',
#  'Ϥᅽ໒วިҽԖज़Ϧљ! \n',
#  '\u038bɄϤԃࡋԃൔ! \n',
#  'ɈҁϦљ\u200e✆䈃錁蘒!\u2000 !!!!!ɈҁϦљж\u0c5bวقΓǺ! \n',
#  'ؠ줠Р?Ġ蘒ఠ뜠ᘠ映Р\uf520 ℠  !  ℠ ℠ ℀‡\u2000‡\u2000‡\u2006\u20c9Р?\u20fa—‽‗\u2005\u2004\u20f9  \n',
#  'ᘠ䴠ᄠ老\u20fa\u200b⁋―⁴\u200f\u20f6\u200c⁛\u2000‡\u2000‡ !  ℠ ℠ ℀‡\u2000‡\u2000‡‖⁍‑₀\u2001\u20fa\u200f\u206e\u2009⁀\u200b⁋\u2006ₐ\u200c⁛\u2000‡ \n',
# ...
